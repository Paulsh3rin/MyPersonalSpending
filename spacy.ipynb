# %%
import spacy
from spacy.training.example import Example
from spacy.util import minibatch, compounding
import random
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import train_test_split

# %%
file_path = 'RawData/CheqMay23-June24.csv'
df = pd.read_csv(file_path)
pd.set_option('display.max_colwidth', 79)
df.head(30)
# Out:
#           Date  \
# 0   2024-06-28
# 1   2024-06-28
# 2   2024-06-28
# 3   2024-06-28
# 4   2024-06-28
# 5   2024-06-27
# 6   2024-06-26
# 7   2024-06-26
# 8   2024-06-26
# 9   2024-06-26
# 10  2024-06-25
# 11  2024-06-25
# 12  2024-06-25
# 13  2024-06-25
# 14  2024-06-25
# 15  2024-06-25
# 16  2024-06-24
# 17  2024-06-24
# 18  2024-06-24
# 19  2024-06-24
# 20  2024-06-24
# 21  2024-06-24
# 22  2024-06-24
# 23  2024-06-21
# 24  2024-06-21
# 25  2024-06-21
# 26  2024-06-21
# 27  2024-06-21
# 28  2024-06-20
# 29  2024-06-20
#
#                                                                        Transaction  \
# 0    Branch Transaction SERVICE CHARGE CAPPED MONTHLY FEE$16.95 RECORD-KEEPING N/A
# 1             Point of Sale - Interac RETAIL PURCHASE 000001001980 WALMART STORE #
# 2             Point of Sale - Interac RETAIL PURCHASE 000001001590 WALMART STORE #
# 3             Point of Sale - Interac RETAIL PURCHASE 000001001358 WALMART STORE #
# 4             Point of Sale - Interac RETAIL PURCHASE 000001001351 WALMART STORE #
# 5             Point of Sale - Interac RETAIL PURCHASE 000001001037 WALMART STORE #
# 6             Point of Sale - Interac RETAIL PURCHASE 000001001808 WALMART STORE #
# 7             Point of Sale - Interac RETAIL PURCHASE 000001001009 WALMART STORE #
# 8             Point of Sale - Interac RETAIL PURCHASE 417808109688 MCDONALD'S #400
# 9             Point of Sale - Interac RETAIL PURCHASE 000001001772 WALMART STORE #
# 10            Point of Sale - Interac RETAIL PURCHASE 417715222247 TIM HORTONS #26
# 11            Point of Sale - Interac RETAIL PURCHASE 000001033037 PANAGO #167 WHI
# 12            Point of Sale - Interac RETAIL PURCHASE 000001001385 WALMART STORE #
# 13            Point of Sale - Interac RETAIL PURCHASE 417710262245 MCDONALD'S #400
# 14  Point of Sale - Visa Debit VISA DEBIT RETAIL PURCHASE REMITLY* B96FA 417703...
# 15            Point of Sale - Interac RETAIL PURCHASE 417619320515 CANNABIS STREET
# 16            Point of Sale - Interac RETAIL PURCHASE 000001001954 WALMART STORE #
# 17            Point of Sale - Interac RETAIL PURCHASE 417612393713 MCDONALD'S #400
# 18                           Internet Banking E-TRANSFER 011033875793 Biju Mathews
# 19            Point of Sale - Interac RETAIL PURCHASE 000001001262 WALMART STORE #
# 20            Point of Sale - Interac RETAIL PURCHASE 000001001846 WALMART STORE #
# 21  Point of Sale - Visa Debit VISA DEBIT RETAIL PURCHASE GOOGLE *YouTube 41757...
# 22            Point of Sale - Interac RETAIL PURCHASE 417508356035 MCDONALD'S #186
# 23            Point of Sale - Interac RETAIL PURCHASE 417317300973 OSHAWA - GO TVM
# 24            Point of Sale - Interac RETAIL PURCHASE 000001001155 WALMART STORE #
# 25            Point of Sale - Interac RETAIL PURCHASE 417307391395 MCDONALD'S #400
# 26  Point of Sale - Visa Debit VISA DEBIT RETAIL PURCHASE UBER CANADA/UBE 41730...
# 27              Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP
# 28            Point of Sale - Interac RETAIL PURCHASE 000001001115 HUDSON'S BAY #1
# 29                                 Internet Banking INTERNET TRANSFER 000000118084
#
#      Debit  Credit   account
# 0    16.95    0.00  chequing
# 1    22.24    0.00  chequing
# 2    16.83    0.00  chequing
# 3     3.30    0.00  chequing
# 4     4.34    0.00  chequing
# 5     6.81    0.00  chequing
# 6     7.37    0.00  chequing
# 7     5.90    0.00  chequing
# 8     1.33    0.00  chequing
# 9     9.94    0.00  chequing
# 10    3.66    0.00  chequing
# 11    5.65    0.00  chequing
# 12    1.65    0.00  chequing
# 13    1.33    0.00  chequing
# 14  250.91    0.00  chequing
# 15   22.36    0.00  chequing
# 16    2.36    0.00  chequing
# 17    4.73    0.00  chequing
# 18    0.00  300.00  chequing
# 19    4.65    0.00  chequing
# 20   11.69    0.00  chequing
# 21    6.20    0.00  chequing
# 22    1.98    0.00  chequing
# 23   14.00    0.00  chequing
# 24   10.63    0.00  chequing
# 25    1.33    0.00  chequing
# 26   21.31    0.00  chequing
# 27    0.00  627.49  chequing
# 28   61.01    0.00  chequing
# 29    0.00   50.00  chequing

# %%
# Prepare the training data
def prepare_training_data(df):
    TRAIN_DATA = []
    for _, row in df.iterrows():
        text = row['Transaction']
        entities = []
        words = text.split()
        for i, word in enumerate(words):
            if word.isupper() and i > 0 and words[i-1].isdigit():
                start = text.index(words[i-1])
                end = start + len(words[i-1]) + 1 + len(word)  # Including space
                entities.append((start, end, "VENDOR"))
        if entities:
            TRAIN_DATA.append((text, {"entities": entities}))
    return TRAIN_DATA

# %%
TRAIN_DATA = prepare_training_data(df)
TRAIN_DATA
# Out:
# [('Point of Sale - Interac RETAIL PURCHASE 000001001980 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001590 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001358 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001351 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001037 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001808 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001009 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 417808109688 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001772 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 417715222247 TIM HORTONS #26',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001033037 PANAGO #167 WHI',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001385 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 417710262245 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 417619320515 CANNABIS STREET',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001954 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 417612393713 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001262 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001846 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 417508356035 MCDONALD'S #186",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 417317300973 OSHAWA - GO TVM',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001155 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 417307391395 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 000001001115 HUDSON'S BAY #1",
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 417209449090 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Internet Banking E-TRANSFER 010984703240 SIDDHARTH APPU',
#   {'entities': [(28, 50, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001002239 VALUE VILLAGE #',
#   {'entities': [(40, 58, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 275148026590 SQ *LEGACYTO',
#   {'entities': [(40, 55, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 417012193305 TIM HORTONS #18',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Internet Banking E-TRANSFER 011029261483 SIDDHARTH APPU',
#   {'entities': [(28, 50, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001451 TWISTED ROOTS C',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 416913938455 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001037061 JUG CITY',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001880 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 416807181827 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 416606501762 TIM HORTONS #20',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 416706108305 PRES/55GC95SWV8',
#   {'entities': [(40, 68, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001010 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 416616394227 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 416610912767 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 416514276634 DOLLARAMA # 392',
#   {'entities': [(40, 62, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001659 AGOSTINO'S AND",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001446030 ALMOST PERFECT',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001491 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 416407176430 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 416321301600 WENDY'S #6426",
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Internet Banking E-TRANSFER 010978473090 SIDDHARTH APPU',
#   {'entities': [(28, 50, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 416211148892 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Internet Banking E-TRANSFER 011022254179 SIDDHARTH APPU',
#   {'entities': [(28, 50, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001058 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 416112107994 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001841 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 415912366555 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000052302337 FAMOUS STREET B',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 415714488849 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000010306291 OSHAWA HOUSE CA',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 415615155034 L M TAYLOR SO',
#   {'entities': [(40, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 415515108052 DOLLARAMA #1522',
#   {'entities': [(40, 62, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 415513162092 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001924 TWISTED ROOTS C',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Internet Banking E-TRANSFER 011016794767 SIDDHARTH APPU',
#   {'entities': [(28, 50, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001826 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001440 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 415408401591 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001874 THE BEER STORE',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001760 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001166 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 415212293383 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001291 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001960 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Internet Banking E-TRANSFER 011011985295 SIDDHARTH APPU',
#   {'entities': [(28, 50, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001596 AGOSTINO'S AND",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 414819182708 OSMOWS SIMCOE S',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001449 MARY JANE'S - O",
#   {'entities': [(40, 57, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001042 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001314 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001805094 SOBEYS #925',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001910 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001501 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001790463 FRESHCO #3883',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001013 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 414211195501 WENDY'S #6697",
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 414208291597 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001629 NORTHERN HELM C',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001730145 FRESHCO #3888',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001730132 FRESHCO #3888',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 414013298020 DOLLARAMA # 889',
#   {'entities': [(40, 62, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001259050 LCBO/RAO #0152',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001936 ODD BURGER WHIT',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001135 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001599 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001187 AGOSTINO'S AND",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 413415477795 MARK'S STORE #7",
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 413319504427 TIM HORTONS #21',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 413319496269 TIM HORTONS #21',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001498 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001317 THE BEER STORE',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001277 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001489 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 991573520510 MISSION THRIFT',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000076306495 HABIB MEAT AND',
#   {'entities': [(40, 58, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 413012188878 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 412913473545 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001683 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 412907361906 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 412818313352 DOMINOS PIZZA #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 915001001007 OSHAWA PUBLIC L',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001913 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 412807389211 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001571 AGOSTINO'S AND",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 412311162435 DOLLARAMA # 392',
#   {'entities': [(40, 62, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001315 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 412208360906 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 412113163737 DOLLARAMA # 435',
#   {'entities': [(40, 62, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 412109336442 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 412023156112 PETRO CANADA006',
#   {'entities': [(40, 58, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 412018770832 TIM HORTONS #12',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001962 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 411816401764 TIM HORTONS #06',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000005304005 RUCHI WORLD',
#   {'entities': [(40, 58, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001149 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 411709424377 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 411616406442 CANNABIS STREET',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001014 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001240 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 411414368656 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001634 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 411208297052 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 411019355654 PRESTO UNION ST',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 411019854082 INS MARKET',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000094303290 BENNYS BARBEQUE',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 411012452088 DURHAM COLLEGE',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001196 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 410711302207 TIM HORTONS #39',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 410616842763 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 410515243632 DOLLARAMA #1522',
#   {'entities': [(40, 62, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001175038 LCBO/RAO #432',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001960 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 410507160891 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001497 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 410412330580 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001419 AGOSTINO'S AND",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001875 BUD RUNNERS CAN',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 409814262940 PAPA JOHN'S PIZ",
#   {'entities': [(40, 57, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001107 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 409709132349 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 409617489596 CANNABIS STREET',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 409610417821 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001171 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001146 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001661 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 409508392999 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 409419820784 UOIT THE SMOOTH',
#   {'entities': [(40, 57, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001003 LUCKY SUPERMARK',
#   {'entities': [(40, 58, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 409409308514 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 409409276000 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001962 AGOSTINO'S AND",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001038 SHOPPERS DRUG M',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001215 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001898 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 409015275489 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001943 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001085 LUCKY SUPERMARK',
#   {'entities': [(40, 58, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 408715349962 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 408712319940 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 408518198604 DOLLARAMA # 531',
#   {'entities': [(40, 62, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001443077 CINNABON',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 408517128922 BAR BURRITO OSH',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 408516099549 UOIT THE SMOOTH',
#   {'entities': [(40, 57, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001061293 FRESHCO #9587',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001137 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 408216480302 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001865 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001160 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 408108225943 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001157 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 408007426358 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 407913777238 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 407817368276 UOIT THE SMOOTH',
#   {'entities': [(40, 57, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 407813245299 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001878 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 407708156760 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001347 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 407608462803 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 407518237188 OSMOWS SIMCOE S',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001047 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 407511498057 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 407508163915 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001321 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001669 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 407408323320 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY 1000011968 HOURLY PAYROLL',
#   {'entities': [(30, 47, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001291 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 407307409637 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 001001001646 DYLAN'S NF OSHA",
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001564 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 332912176013 PRESSE CAFE',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 332917116322 SH VENDING80036',
#   {'entities': [(40, 55, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 332912139123 PRESSE CAFE',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001490 PICOCOOLER',
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY 1000005324 HOURLY PAYROLL',
#   {'entities': [(30, 47, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 332619829724 UOIT THE SMOOTH',
#   {'entities': [(40, 57, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 332516129422 UOIT THE SMOOTH',
#   {'entities': [(40, 57, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001910 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 332315144831 PRESTO UNION ST',
#   {'entities': [(40, 59, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 332219529163 YOGEN FRUZ OSHA',
#   {'entities': [(40, 58, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001295 THE BEER STORE',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001070248 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY 1000005036 HOURLY PAYROLL',
#   {'entities': [(30, 47, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY 1000004826 HOURLY PAYROLL',
#   {'entities': [(30, 47, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 331918593441 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 331816950995 TIM HORTONS #19',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001069261 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001016042 LCBO/RAO #0378',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001315 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001314 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001064232 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001275 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001274 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001642 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001641 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001254 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001252 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001248 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001062077 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001228 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001219 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 330916855428 TIM HORTONS #19',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 330907276395 TIM HORTONS #16',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001731 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 330715696393 TIM HORTONS #19',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 330615096680 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 290001001101 KFC #1374',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001240 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 330318385716 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001053001 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001055238 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 330013470596 TIM HORTONS #19',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 330012424001 NEW YORK FRIES',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001054 THE BEER STORE',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Electronic Funds Transfer PAY Wage/salary 003 WAL-MART CANADA CORP',
#   {'entities': [(42, 54, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 328417155139 TIM HORTONS #19',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 328418568636 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 328417517668 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001988 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001986 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001034268 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 328317926650 TIM HORTONS #19',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 328208124731 TIM HORTONS #19',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001831 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 327907458633 TIM HORTONS #26',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001032127 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 327718758904 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 327717710701 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 327607638872 TIM HORTONS #16',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001555 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001466 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001027252 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001028 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 327219191813 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ("Point of Sale - Interac RETAIL PURCHASE 327216145731 MCDONALD'S #400",
#   {'entities': [(40, 63, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001406 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 326912130887 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001022117 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 326818715299 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 326813530141 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001491 THE BEER STORE',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001483 THE BEER STORE',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 326512524171 TIM HORTONS #16',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001018075 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 001001001188 ADA*VENDING MAC',
#   {'entities': [(40, 64, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 326212401369 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001015253 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001101076 LCBO/RAO #753',
#   {'entities': [(40, 61, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 326115878536 TIM HORTONS #24',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001013058 FRESHCO 9585',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 325710674724 TIM HORTONS #26',
#   {'entities': [(40, 56, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001136 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Point of Sale - Interac RETAIL PURCHASE 000001001135 WALMART STORE #',
#   {'entities': [(40, 60, 'VENDOR')]}),
#  ('Internet Banking INTERNET BILL PAY 000000214425 DURHAM COLLEGE - TUITION',
#   {'entities': [(35, 54, 'VENDOR')]}),
#  ('Internet Banking E-TRANSFER 104700855923 JOYAL JOHN',
#   {'entities': [(28, 46, 'VENDOR')]}),
#  ('Internet Banking INTERNET BILL PAY 000000112561 DURHAM COLLEGE - TUITION',
#   {'entities': [(35, 54, 'VENDOR')]})]

# %%
# Split data into training and evaluation sets
train_data, eval_data = train_test_split(TRAIN_DATA, test_size=0.2, random_state=42)

# %%
# Load the spaCy model
nlp = spacy.blank("en")

# %%
# Create a new NER component
ner = nlp.add_pipe("ner")

# %%
# Add the labels to the NER component
for _, annotations in TRAIN_DATA:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
# Disable other components
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
with nlp.disable_pipes(*other_pipes):
    optimizer = nlp.begin_training()
    for itn in range(10):
        random.shuffle(TRAIN_DATA)
        losses = {}
        batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            texts, annotations = zip(*batch)
            examples = [Example.from_dict(nlp.make_doc(text), annotation) for text, annotation in zip(texts, annotations)]
            nlp.update(examples, drop=0.5, losses=losses)
        print(f"Losses at iteration {itn}: {losses}")
# Out:
# Losses at iteration 0: {'ner': 638.2162051789711}
# Losses at iteration 1: {'ner': 94.31793750502288}
# Losses at iteration 2: {'ner': 44.920556184678006}
# Losses at iteration 3: {'ner': 27.522480645738796}
# Losses at iteration 4: {'ner': 11.79882140821707}
# Losses at iteration 5: {'ner': 18.27317260512596}
# Losses at iteration 6: {'ner': 10.937629911489877}
# Losses at iteration 7: {'ner': 3.562948391863481}
# Losses at iteration 8: {'ner': 8.355990328526751}
# Losses at iteration 9: {'ner': 2.588236901588966}

# %%
# Save the trained model
nlp.to_disk("ner_model")

# %%
# Load the trained model
nlp = spacy.load("ner_model")

# %%
# Function to predict vendor names in a transaction text and extract only the vendor names
def predict_vendor(text):
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ == "VENDOR":
            # Remove the digits and keep only the vendor name
            vendor_name = " ".join([word for word in ent.text.split() if not word.isdigit()])
            return vendor_name
    return None

# %%
# Evaluation function
def evaluate_model(nlp, eval_data):
    true_entities = []
    pred_entities = []
    for text, annotations in eval_data:
        doc = nlp(text)
        true_entities.extend([(ent[0], ent[1], ent[2]) for ent in annotations['entities']])
        pred_entities.extend([(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents if ent.label_ == "VENDOR"])

    y_true = [1 if ent in true_entities else 0 for ent in pred_entities]
    y_pred = [1] * len(pred_entities)
    
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='binary')
    return precision, recall, f1
# Evaluate the model
precision, recall, f1 = evaluate_model(nlp, eval_data)
print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, F1-score: {f1:.2f}")
# Out:
# Precision: 1.00, Recall: 1.00, F1-score: 1.00

# %%
# Example usage
transaction = "Point of Sale - Interac RETAIL PURCHASE 000001001590 WALMART STORE #	"
print(predict_vendor(transaction))
# Out:
# WALMART

# %%
# Apply the prediction function to each row in the dataframe and store the results in a new column
df['vendors'] = df['Transaction'].apply(lambda x: predict_vendor(x))

# Display the first few rows of the updated dataframe
df.head(50)
# Out:
#           Date  \
# 0   2024-06-28
# 1   2024-06-28
# 2   2024-06-28
# 3   2024-06-28
# 4   2024-06-28
# 5   2024-06-27
# 6   2024-06-26
# 7   2024-06-26
# 8   2024-06-26
# 9   2024-06-26
# 10  2024-06-25
# 11  2024-06-25
# 12  2024-06-25
# 13  2024-06-25
# 14  2024-06-25
# 15  2024-06-25
# 16  2024-06-24
# 17  2024-06-24
# 18  2024-06-24
# 19  2024-06-24
# 20  2024-06-24
# 21  2024-06-24
# 22  2024-06-24
# 23  2024-06-21
# 24  2024-06-21
# 25  2024-06-21
# 26  2024-06-21
# 27  2024-06-21
# 28  2024-06-20
# 29  2024-06-20
# 30  2024-06-20
# 31  2024-06-20
# 32  2024-06-20
# 33  2024-06-19
# 34  2024-06-19
# 35  2024-06-19
# 36  2024-06-19
# 37  2024-06-18
# 38  2024-06-18
# 39  2024-06-18
# 40  2024-06-17
# 41  2024-06-17
# 42  2024-06-17
# 43  2024-06-17
# 44  2024-06-17
# 45  2024-06-17
# 46  2024-06-17
# 47  2024-06-17
# 48  2024-06-14
# 49  2024-06-14
#
#                                                                        Transaction  \
# 0    Branch Transaction SERVICE CHARGE CAPPED MONTHLY FEE$16.95 RECORD-KEEPING N/A
# 39  Point of Sale - Visa Debit VISA DEBIT RETAIL PURCHASE DOORDASHREETAJR 41692...
# 40            Point of Sale - Interac RETAIL PURCHASE 416913938455 TIM HORTONS #24
# 41                   Point of Sale - Interac RETAIL PURCHASE 000001037061 JUG CITY
# 42            Point of Sale - Interac RETAIL PURCHASE 000001001880 WALMART STORE #
# 43            Point of Sale - Interac RETAIL PURCHASE 416807181827 MCDONALD'S #400
# 44  Point of Sale - Visa Debit VISA DEBIT RETAIL PURCHASE UBER* PENDING 4168086...
# 45            Point of Sale - Interac RETAIL PURCHASE 416606501762 TIM HORTONS #20
# 46            Point of Sale - Interac RETAIL PURCHASE 416706108305 PRES/55GC95SWV8
# 47            Point of Sale - Interac RETAIL PURCHASE 000001001010 WALMART STORE #
# 48            Point of Sale - Interac RETAIL PURCHASE 416616394227 MCDONALD'S #400
# 49            Point of Sale - Interac RETAIL PURCHASE 416610912767 TIM HORTONS #24
#
#      Debit  Credit   account          vendors
# 0    16.95    0.00  chequing             None
# 1    22.24    0.00  chequing          WALMART
# 2    16.83    0.00  chequing          WALMART
# 3     3.30    0.00  chequing          WALMART
# 4     4.34    0.00  chequing          WALMART
# 5     6.81    0.00  chequing          WALMART
# 6     7.37    0.00  chequing          WALMART
# 7     5.90    0.00  chequing          WALMART
# 8     1.33    0.00  chequing       MCDONALD'S
# 9     9.94    0.00  chequing          WALMART
# 10    3.66    0.00  chequing              TIM
# 11    5.65    0.00  chequing           PANAGO
# 12    1.65    0.00  chequing          WALMART
# 13    1.33    0.00  chequing       MCDONALD'S
# 14  250.91    0.00  chequing
# 15   22.36    0.00  chequing         CANNABIS
# 16    2.36    0.00  chequing          WALMART
# 17    4.73    0.00  chequing       MCDONALD'S
# 18    0.00  300.00  chequing             Biju
# 19    4.65    0.00  chequing          WALMART
# 20   11.69    0.00  chequing          WALMART
# 21    6.20    0.00  chequing             None
# 22    1.98    0.00  chequing       MCDONALD'S
# 23   14.00    0.00  chequing           OSHAWA
# 24   10.63    0.00  chequing          WALMART
# 25    1.33    0.00  chequing       MCDONALD'S
# 26   21.31    0.00  chequing             None
# 27    0.00  627.49  chequing         WAL-MART
# 28   61.01    0.00  chequing         HUDSON'S
# 29    0.00   50.00  chequing
# 30    4.19    0.00  chequing       MCDONALD'S
# 31   75.00    0.00  chequing             Tomi
# 32    0.00   25.00  chequing        SIDDHARTH
# 33   25.17    0.00  chequing            VALUE
# 34   33.90    0.00  chequing               SQ
# 35    1.67    0.00  chequing              TIM
# 36    0.00   10.50  chequing        SIDDHARTH
# 37   88.14    0.00  chequing             None
# 38   21.46    0.00  chequing          TWISTED
# 39   12.33    0.00  chequing  DOORDASHREETAJR
# 40    5.64    0.00  chequing              TIM
# 41    9.05    0.00  chequing              JUG
# 42   20.35    0.00  chequing          WALMART
# 43    1.67    0.00  chequing       MCDONALD'S
# 44   19.94    0.00  chequing
# 45    3.97    0.00  chequing              TIM
# 46    3.30    0.00  chequing  PRES/55GC95SWV8
# 47   14.88    0.00  chequing          WALMART
# 48    2.09    0.00  chequing       MCDONALD'S
# 49    3.71    0.00  chequing              TIM
